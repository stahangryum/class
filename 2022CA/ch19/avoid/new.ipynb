# %%
if (!require(rvest)) install.packages('rvest')
library(rvest)

if (!require(tidyverse)) install.packages('tidyverse')
library(tidyverse)
library(dplyr)

# %%
library(dplyr)

# %%
select(tables, value, starts_with = "제")
# Out:
# Error in `select()`:
# ! Can't subset columns that don't exist.
# x Column `제` doesn't exist.
# Traceback:
#
# 1. select(tables, value, starts_with = "제")
# 2. select.data.frame(tables, value, starts_with = "제")
# 3. tidyselect_fix_call(tidyselect::eval_select(expr(c(...)), .data),
#  .     call = error_call)
# 4. withCallingHandlers(expr, error = function(cnd) {
#  .     cnd$call <- call
#  .     cnd$parent <- NULL
#  .     cnd_signal(cnd)
#  . })
# 5. tidyselect::eval_select(expr(c(...)), .data)
# 6. eval_select_impl(data, names(data), as_quosure(expr, env), include = include,
#  .     exclude = exclude, strict = strict, name_spec = name_spec,
#  .     allow_rename = allow_rename, error_call = error_call, )
# 7. with_subscript_errors(vars_select_eval(vars, expr, strict = strict,
#  .     data = x, name_spec = name_spec, uniquely_named = uniquely_named,
#  .     allow_rename = allow_rename, type = type, error_call = error_call),
#  .     type = type)
# ...

# %%
tables = tables %>% as_tibble

# %%
tables %>% startsWith('제')
# Out:
#  [1] FALSE FALSE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE  TRUE
# [13]  TRUE  TRUE  TRUE  TRUE FALSE FALSE  TRUE FALSE  TRUE  TRUE  TRUE  TRUE
# [25] FALSE  TRUE  TRUE FALSE FALSE  TRUE  TRUE FALSE  TRUE FALSE  TRUE FALSE
# [37] FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [73] FALSE FALSE FALSE FALSE FALSE FALSE

# %%
tables %>% startsWith('제') %>% grep(tables)
# Out:
# Warning message in grep(., tables):
# "인자 'pattern'는 반드시 길이가 1 보다 커야 하고, 오로지 첫번째 요소만이 사용될 것입니다"
# integer(0)

# %%
tables
# Out:
#  [1] "대수\n\n묘호 · 군호\n\n생몰년도\n재위\n\n휘\n\n존호 및 시호\n\n능묘\n\n비고\n"
#  [2] "명 · 청에서 받은시호\n\n조선에서 추숭한존호 및 시호\n"
#  [3] "제1대\n\n\n태조太祖\n\n1335년 - 1408년\n1392년 - 1398년<U+00A0><U+00A0>\n\n성계 成桂\n단 旦<U+00A0><U+00A0>\n\n강헌 康獻\n -[4]<U+00A0><U+00A0>\n\n지인계운성문신무대왕至仁啓運聖文神武大王\n지인계운응천조통광훈영명성문신무정의광덕고황제至仁啓運應天肇統廣勳永命聖文神武正義光德高皇帝\n\n건원릉健元陵\n\n고황제 高皇帝\n"
#  [4] "제2대\n\n정종定宗\n\n1357년 - 1419년\n1398년 - 1400년\n\n방과 芳果\n경 <U+66D4>\n\n공정 恭靖\n\n의문장무온인순효대왕懿文莊武溫仁順孝大王\n\n후릉厚陵\n\n영안대군 永安大君\n"
#  [5] "제3대\n\n태종太宗\n\n1367년 - 1422년\n1400년 - 1418년\n\n방원 芳遠\n\n공정 恭定\n\n성덕신공문무광효대왕聖德神功文武光孝大王\n성덕신공건천체극대정문무예철성렬광효대왕聖德神功建天體極大正文武睿哲成烈光孝大王\n\n헌릉獻陵\n\n정안대군 靖安大君\n"
#  [6] "제4대\n\n\n세종世宗\n\n1397년 - 1450년\n1418년 - 1450년\n\n도 <U+7979>\n\n장헌 莊憲\n\n영문예무인성명효대왕英文睿武仁聖明孝大王\n\n영릉英陵\n\n충녕대군 忠寧大君\n"
#  [7] "제5대\n\n문종文宗\n\n1414년 - 1452년\n1450년 - 1452년\n\n향 珦\n\n공순 恭順\n\n흠명인숙광문성효대왕欽明仁肅光文聖孝大王\n\n현릉顯陵\n\n\n"
#  [8] "제6대\n\n단종端宗\n\n1441년 - 1457년\n1452년 - 1455년\n\n홍위 弘暐\n\n-\n\n공의온문순정안장경순돈효대왕恭懿溫文純定安莊景順郭孝大王\n\n장릉莊陵\n\n노산군 魯山君노산대군 魯山大君\n"
# ...

# %%
tables[]
# Out:
#  [1] "제1대\n\n\n태조太祖\n\n1335년 - 1408년\n1392년 - 1398년<U+00A0><U+00A0>\n\n성계 成桂\n단 旦<U+00A0><U+00A0>\n\n강헌 康獻\n -[4]<U+00A0><U+00A0>\n\n지인계운성문신무대왕至仁啓運聖文神武大王\n지인계운응천조통광훈영명성문신무정의광덕고황제至仁啓運應天肇統廣勳永命聖文神武正義光德高皇帝\n\n건원릉健元陵\n\n고황제 高皇帝\n"
#  [2] "제2대\n\n정종定宗\n\n1357년 - 1419년\n1398년 - 1400년\n\n방과 芳果\n경 <U+66D4>\n\n공정 恭靖\n\n의문장무온인순효대왕懿文莊武溫仁順孝大王\n\n후릉厚陵\n\n영안대군 永安大君\n"
#  [3] "제3대\n\n태종太宗\n\n1367년 - 1422년\n1400년 - 1418년\n\n방원 芳遠\n\n공정 恭定\n\n성덕신공문무광효대왕聖德神功文武光孝大王\n성덕신공건천체극대정문무예철성렬광효대왕聖德神功建天體極大正文武睿哲成烈光孝大王\n\n헌릉獻陵\n\n정안대군 靖安大君\n"
#  [4] "제4대\n\n\n세종世宗\n\n1397년 - 1450년\n1418년 - 1450년\n\n도 <U+7979>\n\n장헌 莊憲\n\n영문예무인성명효대왕英文睿武仁聖明孝大王\n\n영릉英陵\n\n충녕대군 忠寧大君\n"
#  [5] "제5대\n\n문종文宗\n\n1414년 - 1452년\n1450년 - 1452년\n\n향 珦\n\n공순 恭順\n\n흠명인숙광문성효대왕欽明仁肅光文聖孝大王\n\n현릉顯陵\n\n\n"
#  [6] "제6대\n\n단종端宗\n\n1441년 - 1457년\n1452년 - 1455년\n\n홍위 弘暐\n\n-\n\n공의온문순정안장경순돈효대왕恭懿溫文純定安莊景順郭孝大王\n\n장릉莊陵\n\n노산군 魯山君노산대군 魯山大君\n"
# ...

# %%
target_url <- 'https://ko.wikipedia.org/wiki/%EC%A1%B0%EC%84%A0_%EA%B5%AD%EC%99%95'
html <- read_html(target_url)

order = 1

tables <- target_url %>%
    read_html() %>%
    html_nodes('table[class=wikitable]') %>%
    html_nodes('tr') %>%    
    html_text()

tables
# Out:
#  [1] "대수\n\n묘호 · 군호\n\n생몰년도\n재위\n\n휘\n\n존호 및 시호\n\n능묘\n\n비고\n"
#  [2] "명 · 청에서 받은시호\n\n조선에서 추숭한존호 및 시호\n"
#  [3] "제1대\n\n\n태조太祖\n\n1335년 - 1408년\n1392년 - 1398년<U+00A0><U+00A0>\n\n성계 成桂\n단 旦<U+00A0><U+00A0>\n\n강헌 康獻\n -[4]<U+00A0><U+00A0>\n\n지인계운성문신무대왕至仁啓運聖文神武大王\n지인계운응천조통광훈영명성문신무정의광덕고황제至仁啓運應天肇統廣勳永命聖文神武正義光德高皇帝\n\n건원릉健元陵\n\n고황제 高皇帝\n"
#  [4] "제2대\n\n정종定宗\n\n1357년 - 1419년\n1398년 - 1400년\n\n방과 芳果\n경 <U+66D4>\n\n공정 恭靖\n\n의문장무온인순효대왕懿文莊武溫仁順孝大王\n\n후릉厚陵\n\n영안대군 永安大君\n"
#  [5] "제3대\n\n태종太宗\n\n1367년 - 1422년\n1400년 - 1418년\n\n방원 芳遠\n\n공정 恭定\n\n성덕신공문무광효대왕聖德神功文武光孝大王\n성덕신공건천체극대정문무예철성렬광효대왕聖德神功建天體極大正文武睿哲成烈光孝大王\n\n헌릉獻陵\n\n정안대군 靖安大君\n"
#  [6] "제4대\n\n\n세종世宗\n\n1397년 - 1450년\n1418년 - 1450년\n\n도 <U+7979>\n\n장헌 莊憲\n\n영문예무인성명효대왕英文睿武仁聖明孝大王\n\n영릉英陵\n\n충녕대군 忠寧大君\n"
#  [7] "제5대\n\n문종文宗\n\n1414년 - 1452년\n1450년 - 1452년\n\n향 珦\n\n공순 恭順\n\n흠명인숙광문성효대왕欽明仁肅光文聖孝大王\n\n현릉顯陵\n\n\n"
#  [8] "제6대\n\n단종端宗\n\n1441년 - 1457년\n1452년 - 1455년\n\n홍위 弘暐\n\n-\n\n공의온문순정안장경순돈효대왕恭懿溫文純定安莊景順郭孝大王\n\n장릉莊陵\n\n노산군 魯山君노산대군 魯山大君\n"
# ...
