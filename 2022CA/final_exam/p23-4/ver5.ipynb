# %%
# Import packages
if (!require(pacman)) install.packages('pacman')
library(pacman)
pacman::p_load("rvest", "tidyverse")
# Out:
# 필요한 패키지를 로딩중입니다: pacman
#
# Warning message:
# "패키지 'pacman'는 R 버전 4.1.3에서 작성되었습니다"

# %%
getLinks <- function(termGbn){ # Input 'week' or 'month'
    base_url <- 'http://gaonchart.co.kr/main/section/chart/online.gaon?nationGbn=T&serviceGbn=ALL'
    sample_url <- paste0(base_url, '&termGbn=', termGbn)
    dates <-     
        read_html(sample_url) %>%
        html_nodes('div[class=fr]') %>%
        html_nodes('select') %>%
        html_nodes('option') %>%
        html_attr('value') %>%
        str_subset(pattern = '^[0-9]{6}$')
    
    # 'dates'(YYYYMM) will be divided into hitYear(YYYY) and targetTime(MM).
    # Ex) dates <- 202221.
    hitYear <-
        dates %>%
        substr(1,4) # Ex) hitYear <- 2022.

    targetTime <-
        dates %>%
        substr(5,6) # Ex) hitYear <- 21.
    
    complete_url <- paste0(base_url, '&targetTime=', targetTime, '&hitYear=', hitYear, '&termGbn=', termGbn)
    return(complete_url) # Return all urls
}

# %%
getPage <- function(target_url){ # Input complete URL including targetTime, hitYear, and termGbn
    
    url_splited <- 
        target_url %>%
        strsplit('=|&') %>%
        unlist()
    
    year_temp <- 
        url_splited %>%
        str_subset('^[0-9]{2,4}$') %>%
        rev() %>%
        paste0(collapse = '')
    
    termGbn <- 
        url_splited %>%
        '['(length(url_splited))

    html_chart <- read_html(target_url) %>%
        html_nodes('div[class=chart]')

    td <- html_chart %>% 
        html_nodes('td') %>%
        html_text() %>%
        str_split('\\n|\\||\\r|\\t') %>%
        unlist() %>%
        str_subset('^$', negate = TRUE)

    change_grp <- html_chart %>%
        html_nodes('td[class=change]') %>%
        html_nodes('span') %>%
        html_attr('class')
    
    # sort by 'PLAY'
    ## Ex) 
    ## "~~", "~~", "PLAY", "~~", "~~", "PLAY", "~~", "~~", "PLAY"
    ## to
    ## |~~|~~|'PLAY'|
    ## |~~|~~|'PLAY'|
    ## |~~|~~|'PLAY'|
    
    # 'Gaon Score' was newly created in Jan 2018. 
    ## Before Jan 2018 : chart_piece has 11 columns.
    ## After Jan 2018 : chart_piece has 12 columns. 
    index_PLAY <- str_which(td, 'PLAY')
    PLAY_ZONE <- c(11, 12)
    index_TRUE_PLAY <- index_PLAY[index_PLAY %in% PLAY_ZONE][1]

    chart_piece <- td %>% 
        matrix(ncol = index_TRUE_PLAY, byrow = TRUE) %>%
        as_tibble()

    # Note : ifelse always returns an object of the same length as the condition. so we use if/else for this case.
    chart <- tibble(year_temp = year_temp,
                        ranking = chart_piece$V1,
                        change_grp = change_grp,
                        change_val = chart_piece$V2,
                        title = chart_piece$V3,
                        artist = chart_piece$V4,
                        gaon_index = if (ncol(chart_piece) == 12) chart_piece$V6 else NA,  
                        production = if(ncol(chart_piece) == 12) chart_piece$V7 else chart_piece$V6,
                        distribution = if(ncol(chart_piece) == 12) chart_piece$V8 else chart_piece$V7)

    chart$gaon_index <- chart$gaon_index %>% 
                            str_replace_all('[^0-9]', '') 
    colnames(chart)[1] <- ifelse(termGbn == 'week', 'year_week', 'year_month')

    return(chart) # Return chart of the 'target_url'.
}

# %%
getPage(monthLinks[1])
# Out:
#     year_month ranking change_grp change_val
# 1   202204     1       new        new
# 2   202204     2       up         1
# 3   202204     3       up         23
# 4   202204     4       new        new
# 5   202204     5       up         3
# 6   202204     6       down       4
# 7   202204     7       down       3
# 8   202204     8       down       7
# 9   202204     9       down       4
# 10  202204     10      new        new
# 11  202204     11      down       4
# 12  202204     12      down       1
# 13  202204     13      down       7
# 14  202204     14      down       4
# 15  202204     15      down       1
# 16  202204     16      NA         -
# 17  202204     17      up         1
# 18  202204     18      down       5
# 19  202204     19      up         1
# 20  202204     20      down       8
# 21  202204     21      up         8
# 22  202204     22      up         48
# 23  202204     23      up         2
# 24  202204     24      up         93
# 25  202204     25      down       1
# 26  202204     26      down       7
# 27  202204     27      up         HOT
# 28  202204     28      down       13
# 29  202204     29      new        new
# 30  202204     30      down       21
# <U+22EE>   <U+22EE>   <U+22EE> <U+22EE>   <U+22EE>
# 171 202204     171     down       24
# 172 202204     172     new        new
# 173 202204     173     new        new
# 174 202204     174     down       33
# 175 202204     175     down       14
# 176 202204     176     down       7
# 177 202204     177     down       34
# 178 202204     178     new        new
# 179 202204     179     up         HOT
# 180 202204     180     down       34
# 181 202204     181     down       22
# 182 202204     182     down       15
# 183 202204     183     up         39
# 184 202204     184     down       8
# 185 202204     185     down       90
# 186 202204     186     NA         -
# 187 202204     187     up         10
# 188 202204     188     down       55
# 189 202204     189     down       14
# 190 202204     190     down       121
# 191 202204     191     down       28
# 192 202204     192     down       5
# 193 202204     193     new        new
# 194 202204     194     down       58
# 195 202204     195     down       43
# 196 202204     196     new        new
# 197 202204     197     down       26
# 198 202204     198     new        new
# 199 202204     199     up         72
# 200 202204     200     up         64
#     title                                          artist
# 1   봄여름가을겨울 (Still Life)                    BIGBANG (빅뱅)
# 2   TOMBOY                                         (여자)아이들
# 3   Feel My Rhythm                                 레드벨벳(Red Velvet)
# 4   LOVE DIVE                                      IVE (아이브)
# 5   사랑인가 봐                                    멜로망스(Melomance)
# 6   GANADARA (Feat. 아이유)                        박재범
# 7   취중고백                                       김민석
# 8   INVU                                           태연 (TAEYEON)
# 9   듣고 싶을까                                    MSG워너비(M.O.M)
# 10  우리들의 블루스                                임영웅
# 11  사랑은 늘 도망가                               임영웅
# 12  ELEVEN                                         IVE (아이브)
# 13  RUN2U                                          STAYC(스테이씨)
# 14  SMILEY (Feat. BIBI)                            YENA(최예나)
# 15  다정히 내 이름을 부르면                        경서예지, 전건호
# 16  신호등                                         이무진
# 17  Stay                                           The Kid LAROI, Justin Bieber
# 18  회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom) sokodomo
# 19  드라마                                         아이유 (IU)
# 20  언제나 사랑해                                  케이시 (Kassy)
# 21  존재만으로                                     원슈타인
# 22  버퍼링 (Glitch Mode)                           NCT DREAM
# 23  strawberry moon                                아이유 (IU)
# 24  MY BAG                                         (여자)아이들
# 25  Next Level                                     aespa
# 26  리무진 (Feat. MINO) (Prod. GRAY)               BE`O (비오)
# 27  Real Love                                      오마이걸 (OH MY GIRL)
# 28  Step Back                                      GOT the beat
# 29  LOVE me                                        BE`O (비오)
# 30  abcdefu                                        GAYLE
# <U+22EE>   <U+22EE>                                       <U+22EE>
# 171 사계 (Four Seasons)                            태연 (TAEYEON)
# 172 사건의 지평선                                  윤하 (YOUNHA)
# 173 All 4 Nothing (I`m So In Love)                 Lauv
# 174 늦은 후회                                      조현아
# 175 Bad                                            Christopher
# 176 parachute                                      John K
# 177 우린 어떠한 별보다 빛날 거야                   이하이
# 178 찾았다 내 사랑                                 V.O.S
# 179 Love Blossom (러브블러썸)                      케이윌 (K.Will)
# 180 비와 당신                                      이무진
# 181 너를 만나                                      폴킴
# 182 어푸 (Ah puh)                                  아이유 (IU)
# 183 아이와 나의 바다                               아이유 (IU)
# 184 아로하                                         조정석
# 185 사랑이 아니었다고 말하지 마요                  이예준
# 186 Shape of You                                   Ed Sheeran
# 187 Dolphin                                        오마이걸 (OH MY GIRL)
# 188 Life Goes On                                   방탄소년단
# 189 Rainy day (Feat. ASH ISLAND, Skinny Br...      PATEKO (파테코)
# 190 그래서 그래 (Feat. 윤하)                       에픽하이 (EPIK HIGH)
# 191 거리에서                                       성시경
# 192 마음을 드려요                                  아이유 (IU)
# 193 그대가 있기에                                  노을
# 194 나 그댈위해 시 한편을 쓰겠어                   케이시 (Kassy)
# 195 좋아좋아                                       조정석
# 196 That That (prod. & feat. SUGA of BTS)          싸이 (Psy)
# 197 첫눈처럼 너에게 가겠다                         에일리 (Ailee)
# 198 Rewind                                         NCT DREAM
# 199 있잖아                                         폴킴
# 200 가보자                                         Xydo (시도)
#     gaon_index production
# 1   168901052  YG Entertainment
# 2   133304108  큐브엔터테인먼트
# 3   111957588  SM Entertainment
# 4   105286003  스타쉽엔터테인먼트
# 5   100850288  플렉스엠
# 6   96954973   MORE VISION
# 7   74844734   프로젝트 리본
# 8   73279966   SM Entertainment
# 9   66582512   NK Company
# 10  65181365   물고기뮤직
# 11  62110385   모스트콘텐츠
# 12  57712208   스타쉽엔터테인먼트
# 13  53644123   하이업엔터테인먼트
# 14  53581468   위에화엔터테인먼트코리아
# 15  53265293   에버그로우
# 16  53164529   쇼플레이
# 17  48041979   Columbia
# 18  47515406   Stone Music Entertainment
# 19  47214931   EDAM엔터테인먼트
# 20  46362387   도토리뮤직
# 21  44751229   스튜디오 마음C, 화앤담픽쳐스
# 22  44733147   SM Entertainment
# 23  41467715   EDAM엔터테인먼트
# 24  41258785   큐브엔터테인먼트
# 25  40828687   SM Entertainment
# 26  40080046   Stone Music Entertainment
# 27  39682135   WM엔터테인먼트
# 28  39486108   SM Entertainment
# 29  39419043   BPM ENTERTAINMENT,SWING ENTERTAINMENT, 페임어스엔터테인먼트
# 30  38185251   Atlantic, Arthouse Records
# <U+22EE>   <U+22EE>   <U+22EE>
# 171 9261829    SM Entertainment
# 172 9236217    C9엔터테인먼트
# 173 9217347    Lauv
# 174 8983480    방구석 캐스팅
# 175 8945355    Parlophone Denmark
# 176 8808851    Epic
# 177 8791514    제나두 엔터테인먼트
# 178 8774867    방구석 캐스팅
# 179 8770338    스타쉽엔터테인먼트
# 180 8767395    스튜디오 마음C, 에그이즈커밍, Stone Music Entertainment
# 181 8676670    뉴런뮤직
# 182 8662455    EDAM엔터테인먼트
# 183 8618047    EDAM엔터테인먼트
# 184 8528790    스튜디오 마음C, 에그이즈커밍, Stone Music Entertainment
# 185 8511377    이예준
# 186 8437651    Atlantic Records UK
# 187 8412140    WM엔터테인먼트
# 188 8367136    BIGHIT MUSIC / HYBE
# 189 8323483    tokkinny records
# 190 8285918    아워즈
# 191 8275724    제로원인터랙티브
# 192 8266031    EDAM엔터테인먼트
# 193 8263190    축가(祝歌)프로젝트
# 194 8198306    넥스타엔터테인먼트
# 195 8189237    스튜디오 마음C, 에그이즈커밍, Stone Music Entertainment
# 196 8140671    피네이션
# 197 8119588    Stone Music Entertainment, 화앤담픽쳐스
# 198 8093160    SM Entertainment
# 199 8081652    스페이스오디티
# 200 7997601    스튜디오 마음C, 화앤담픽쳐스
#     distribution
# 1   YG PLUS
# 2   Kakao Entertainment
# 3   Dreamus
# 4   Kakao Entertainment
# 5   Kakao Entertainment
# 6   Kakao Entertainment
# 7   Warner Music
# 8   Dreamus
# 9   지니뮤직, Stone Music Entertainment
# 10  Dreamus
# 11  NHN벅스
# 12  Kakao Entertainment
# 13  Kakao Entertainment
# 14  지니뮤직, Stone Music Entertainment
# 15  Kakao Entertainment
# 16  Kakao Entertainment
# 17  Sony Music
# 18  지니뮤직
# 19  Kakao Entertainment
# 20  Kakao Entertainment
# 21  YG PLUS
# 22  Dreamus
# 23  Kakao Entertainment
# 24  Kakao Entertainment
# 25  Dreamus
# 26  지니뮤직
# 27  Sony Music
# 28  Dreamus
# 29  Kakao Entertainment
# 30  Warner Music
# <U+22EE>   <U+22EE>
# 171 Dreamus
# 172 Kakao Entertainment
# 173 Universal Music
# 174 Kakao Entertainment
# 175 Warner Music
# 176 Sony Music
# 177 NHN벅스
# 178 Kakao Entertainment
# 179 Kakao Entertainment
# 180 지니뮤직, Stone Music Entertainment
# 181 Kakao Entertainment
# 182 Kakao Entertainment
# 183 Kakao Entertainment
# 184 지니뮤직, Stone Music Entertainment
# 185 Kakao Entertainment
# 186 Warner Music
# 187 Sony Music
# 188 YG PLUS
# 189 YG PLUS
# 190 지니뮤직
# 191 더늠
# 192 Kakao Entertainment
# 193 Kakao Entertainment
# 194 Kakao Entertainment
# 195 지니뮤직, Stone Music Entertainment
# 196 Dreamus
# 197 지니뮤직, Stone Music Entertainment
# 198 Dreamus
# 199 Kakao Entertainment
# 200 YG PLUS

# %%
# Weekly Rankings.
# Time to run : 7~8min.
weekLinks <- getLinks('week')
all_week_pages <- vector('list', length(weekLinks))
for (i in 1:length(all_week_pages)) all_week_pages[[i]] <- getPage(weekLinks[i])
week_final <- do.call('rbind', all_week_pages)
write.table(week_final, 'gaon_week.txt', row.names = FALSE)

# %%
getPage(weekLinks[i]) %>% colnames[1]
# Out:
# [1] "year_week"    "ranking"      "change_grp"   "change_val"   "title"
# [6] "artist"       "gaon_index"   "production"   "distribution"

# %%
# Monthly Rankings.
# Time to run : 1~2min.
monthLinks <- getLinks('month')
all_month_pages <- vector('list', length(monthLinks))

# %%
for (i in 1:length(all_month_pages)) all_month_pages[[i]] <- getPage(monthLinks[i])
month_final <- do.call('rbind', all_month_pages)
write.table(month_final, 'gaon_month.txt', row.names = FALSE)
# Out:
# Warning message:
# "The `x` argument of `as_tibble.matrix()` must have unique column names if `.name_repair` is omitted as of tibble 2.0.0.
# Using compatibility `.name_repair`.
# This warning is displayed once every 8 hours.
# Call `lifecycle::last_lifecycle_warnings()` to see where this warning was generated."
# Error in open.connection(x, "rb"): Timeout was reached: [gaonchart.co.kr] Connection timed out after 10012 milliseconds
# Traceback:
#
# 1. getPage(weekLinks[i])
# 2. read_html(target_url) %>% html_nodes("div[class=chart]")   # at line 10-11 of file <text>
# 3. html_nodes(., "div[class=chart]")
# 4. html_elements(...)
# 5. read_html(target_url)
# 6. read_html.default(target_url)
# 7. suppressWarnings(read_xml(x, encoding = encoding, ..., as_html = TRUE,
#  .     options = options))
# 8. withCallingHandlers(expr, warning = function(w) if (inherits(w,
#  .     classes)) tryInvokeRestart("muffleWarning"))
# 9. read_xml(x, encoding = encoding, ..., as_html = TRUE, options = options)
# 10. read_xml.character(x, encoding = encoding, ..., as_html = TRUE,
#   .     options = options)
# 11. read_xml.connection(con, encoding = encoding, ..., as_html = as_html,
#   .     base_url = x, options = options)
# 12. open(x, "rb")
# 13. open.connection(x, "rb")
